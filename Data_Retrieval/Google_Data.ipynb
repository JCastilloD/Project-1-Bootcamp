# %%
# Dependencies
import requests
import json

# Google developer API key
from config import gkey

# %%
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
place_from_text = "https://maps.googleapis.com/maps/api/place/findplacefromtext/json"
details_url = "https://maps.googleapis.com/maps/api/place/details/json"
geo_url = "https://maps.googleapis.com/maps/api/geocode/json"

#address=1600+Amphitheatre+Parkway,+Mountain+View,+CA&key=

target_address="Estado de Mexico"
target_coordinates = ""
target_search = "Estado de Mexico"
target_radius = 50000
target_type = "restaurant"
target_query = "Estado de Mexico"
place_id = "ChIJOwrrwJKJzYURV6jFn775_sI"
g_id = "e579533b947b1a3233a8029b07477df919791427"
qinput = "Estado de Mexico"
inputtype = "textquery"

params1 = {
    "input" : qinput,
    "inputtype" : inputtype,
    #"id": g_id,
    #"place_id": place_id,
    #"location" : target_coordinates,
    #"keyword" : target_search,
    #"radius" : target_radius,
    #"type" : target_type,
    "key": gkey
}

params2 = {
    "query" : target_query,
    "place_id": place_id,
    #"keyword" : target_search,
    #"radius" : target_radius,
    #"type" : target_type,
    "key": gkey
    #"address" : target_address
}

params3 = {
    #"query" : target_query,
    #"location" : target_coordinates,
    #"keyword" : target_search,
    #"radius" : target_radius,
    #"type" : target_type,
    "key": gkey,
    "address" : target_address
}

params4 = {
    "input" : qinput,
    "inputtype" : inputtype,
    #"id": g_id,
    #"place_id": place_id,
    #"location" : target_coordinates,
    #"keyword" : target_search,
    #"radius" : target_radius,
    #"type" : target_type,
    "key": gkey
}

#response1 = requests.get(base_url, params=params1)
#response2 = requests.get(details_url, params=params2)
#response3 = requests.get(geo_url, params=params3)
response4 = requests.get(place_from_text, params=params4)

# %%
#print(response1.url)
#print(response2.url)
#print(response3.url)
print(response4.url)
# Out:
# https://maps.googleapis.com/maps/api/place/findplacefromtext/json?input=Estado+de+Mexico&inputtype=textquery&key=AIzaSyAwDyEwcf_ffX0otnRMJYklewZ9ywIkxJc

# %%
 # convert response to json
places_data = response.json()

# Print the json (pretty printed)
print(json.dumps(places_data, indent=4, sort_keys=True))
# Out:
# {
#     "html_attributions": [],
#     "next_page_token": "CrQCKgEAAN0899wrdyvyjt_gbiFnf0FqvQTdvU70N535wkQgykzlg0g73BBHr_lu8q3PUVtef6SeJ_8HADxZJc5Cg1VpPojfjEsROMz_gGdGEvmWddeA7JU6s_C5VlXOo49ZVmabTqiaXDeQWH6JJGJDp5sKaIwk3PaANxFEqDPI8KqnLw8jw527h5mLZ62sRAHaAcC8jow51c0qsf2eFTgCK3Ifnio-beukTVc3RJh-172UN5bTlkV-w5ymO-Ud94jArv-SjjspErxoclA4ZFV7JrXdoLZFT5XiJR9VbOWrjGfxyDQWqZylJJaf9eJ0QRTzaBuI2NfzH2fq5Mxqjlr2wl8ph70mEYpYPdXzrYTZSYUdWG90mZIPdsS_Fh518950bNHNJoa4vmTEuLmRo25qq9SJEYESENyqd7L3j5-rx8UuE3OB-OkaFDsMjogHZPf74sWlp9ef-0xqcq_s",
#     "results": [
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 43.5888893,
#                     "lng": -116.2776039
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.59023912989272,
#                         "lng": -116.2762540701073
#                     },
#                     "southwest": {
#                         "lat": 43.58753947010728,
#                         "lng": -116.2789537298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "286cea6abbf1b8ca63e5b1d4223cf74c9998e69e",
#             "name": "Guang Zhou Restaurant",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3036,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/112283839043679804235\">Jim Paulson</a>"
#                     ],
#                     "photo_reference": "CmRaAAAApDvd9VJwUcXBlu4rLpo3zSvegJqO1gjbJblz5xijKvE5YpeFTfcBHd9PWjwFrofN6_ZrRa9xBxd2KPACkcOtfnh3X3InxASkeND2IndplE4L9A4R-NF12uBzancDqK3HEhAKfrZATOMpCUsUo_B9mpFzGhTqhXElHfP6MLPawd8OodCIcJc4nQ",
#                     "width": 4048
#                 }
#             ],
#             "place_id": "ChIJDT-7DlJWrlQRO7rtBTzZf6s",
#             "plus_code": {
#                 "compound_code": "HPQC+HX Boise, Idaho",
#                 "global_code": "85M5HPQC+HX"
#             },
#             "price_level": 1,
#             "rating": 4.1,
#             "reference": "ChIJDT-7DlJWrlQRO7rtBTzZf6s",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 358,
#             "vicinity": "7609 W Overland Rd, Boise"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 43.6487584,
#                     "lng": -116.2461602
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.65017512989272,
#                         "lng": -116.2448953701073
#                     },
#                     "southwest": {
#                         "lat": 43.64747547010727,
#                         "lng": -116.2475950298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "1d24153141ea5604e7f247978036ec0b8f45d75b",
#             "name": "New Garden Chinese Restaurant",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 
a>"
#                     ],
#                     "photo_reference": "CmRaAAAAhr01kllymXTxbLOrZjPUmsiyNuJBkVM5s4SWvKcVpEP1BTVseSgsgYW0c9vEurCt6M9FLHJ9iP3lSjaAndY_jvBizqUYlBiU_cJMJ-AQuaH5GQmAKTilh5Agd3QNsgRZEhAQnCm4qbPCtfsF_2E-reMCGhQ9-uWH5zpEuexwFJeobqFj4S7bfw",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJkevL-_r4rlQRdCX2O8ZXDsM",
#             "plus_code": {
#                 "compound_code": "JQ7W+4Q Boise, Idaho",
#                 "global_code": "85M5JQ7W+4Q"
#             },
#             "price_level": 1,
#             "rating": 3.9,
#             "reference": "ChIJkevL-_r4rlQRdCX2O8ZXDsM",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 173,
#             "vicinity": "601 W Front St, Boise"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 43.590018,
#                     "lng": -116.2418638
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.59136677989272,
#                         "lng": -116.2405863201073
#                     },
#                     "southwest": {
#                         "lat": 43.58866712010728,
#                         "lng": -116.2432859798927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "2a3be484e3d636b3b1bb36a2cdb40d25e7768fe5",
#             "name": "Quik-Wok Restaurant",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 4032,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/115683889569422608978\">Greg Dennler</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAG4DFsgkdt5Wo_ZGIAyygs6_ngMGnLNyoWQWDQ0Tl3APlR3A1WZVXl2Qn7uoAZuXVSYr8ihkA8ghytewlNDiiqhZjuxwWRiurJRuqH66cTwM17wwfTr7sUabtRxl5dpMJEhDyVkfTEK708xLWEUwmUQYrGhTNY_pTPbnTuul41w7FmPutVg05VA",
#                     "width": 1960
#                 }
#             ],
#             "place_id": "ChIJbRshL9JXrlQRDa61aB-RK2E",
#             "plus_code": {
#                 "compound_code": "HQR5+27 Boise, Idaho",
#                 "global_code": "85M5HQR5+27"
#             },
#             "price_level": 1,
#             "rating": 3.4,
#             "reference": "ChIJbRshL9JXrlQRDa61aB-RK2E",
#             "scope": "GOOGLE",
#             "types": [
#                 "meal_delivery",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 324,
#             "vicinity": "4858 W Overland Rd, Boise"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 43.6050103,
#                     "lng": -116.2064403
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.60645682989272,
#                         "lng": -116.2055487201073
#                     },
#                     "southwest": {
#                         "lat": 43.60375717010728,
#                         "lng": -116.2082483798928
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "728d3c53c4fb43573036b3f7145f11c0980565ea",
#             "name": "Panda Express",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2988,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/101664420514119796067\">Tyler S</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAyUqoEjEOyO9dxXOWjziIjBDjhjlkNcWEDTcu3zmdIPt0jUS8ZMxkbsHGPuzi24L47XMEGDXto0YhSaHrU2e_zFWR3t9dlONrSgbD2xoFri7PbiVH0hdJFEUeVwn6SFBuEhDqVpLTkt6frJtKoWgk_KjWGhSPkmKTJaI0ZBzOFRJh3URQGxLfAA",
#                     "width": 5312
#                 }
#             ],
#             "place_id": "ChIJbUOFwlj4rlQRZ_4alQLNUtE",
#             "plus_code": {
#                 "compound_code": "JQ4V+2C Boise, Idaho",
#                 "global_code": "85M5JQ4V+2C"
#             },
#             "price_level": 1,
#             "rating": 3.8,
#             "reference": "ChIJbUOFwlj4rlQRZ_4alQLNUtE",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 38,
#             "vicinity": "1910 W University Dr, Boise"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 43.66537080000001,
#                     "lng": -116.2800739
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.66668547989272,
#                         "lng": -116.2787255701072
#                     },
#                     "southwest": {
#                         "lat": 43.66398582010728,
#                         "lng": -116.2814252298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "57f5dd002ac8f2ce2ae349e7509dda9bbc4ce5c2",
#             "name": "Panda Express",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1080,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/117934514924701003674\">Robert Spence</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAXoKBMze9AAYtzT6A625odjTPDg8fdHuNMIpTG2r9Io4_uhoRdBOFIC9XBJO7qvMTdqzC9jBnIiBV-QDDBmpQLebP5mz5bW2ZmWyGusfgt-9UnB5e8kHPkjWCd2Vp0cOwEhDNHFBgwJQMfBH8Be9fcL-MGhRHAKrwEkWy_q8BXuTZ5XkXpo8fug",
#                     "width": 1920
#                 }
#             ],
#             "place_id": "ChIJLdWyiJ7_rlQRIRdU-1NWqEw",
#             "plus_code": {
#                 "compound_code": "MP89+4X Garden City, Idaho",
#                 "global_code": "85M5MP89+4X"
#             },
#             "price_level": 1,
#             "rating": 4.2,
#             "reference": "ChIJLdWyiJ7_rlQRIRdU-1NWqEw",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 363,
#             "vicinity": "6675 N Glenwood St, Garden City"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 43.6086039,
#                     "lng": -116.2782517
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.61003902989272,
#                         "lng": -116.2767403201073
#                     },
#                     "southwest": {
#                         "lat": 43.60733937010727,
#                         "lng": -116.2794399798927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "2ed6cc10f5ade931ec1fecc1f07910be5091b074",
#             "name": "Panda Express",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/104961771114871630072\">Bobbie Owen</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAghzOFiO4gHp_i3TgC1htgf0C3-HzM5KPGzou9yN3dgBO-p11TnlZPs1hmuLfdtQIeFDEdl7wU2V9aSYsnMOFkE_tvKnTI7ot7GQayk7ie_K0dLXcScyIUtzkqwdRRmzqEhDqZGFd9n91fwVHw2p3UBuvGhQzX_OrKZax94wVEQvge6eDfAOyCw",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJfYBLkWpWrlQRjig0x7oVFfk",
#             "plus_code": {
#                 "compound_code": "JP5C+CM Boise, Idaho",
#                 "global_code": "85M5JP5C+CM"
#             },
#             "price_level": 1,
#             "rating": 3.4,
#             "reference": "ChIJfYBLkWpWrlQRjig0x7oVFfk",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 94,
#             "vicinity": "350 N Milwaukee St, Boise"
#         }
#     ],
#     "status": "OK"
# }
