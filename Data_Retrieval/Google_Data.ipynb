# %%
# Dependencies
import requests
import json
import pandas as pd
import gmaps

# Google developer API key
from config import gkey

gmaps.configure(api_key=gkey)

# %%
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
place_from_text = "https://maps.googleapis.com/maps/api/place/findplacefromtext/json"
details_url = "https://maps.googleapis.com/maps/api/place/details/json"
geo_url = "https://maps.googleapis.com/maps/api/geocode/json"

#address=1600+Amphitheatre+Parkway,+Mountain+View,+CA&key=

target_address="Estado de Mexico"
target_coordinates = ""
target_search = "Estado de Mexico"
target_radius = 50000
target_type = "restaurant"
target_query = "Estado de Mexico"
place_id = "ChIJOwrrwJKJzYURV6jFn775_sI"
g_id = "e579533b947b1a3233a8029b07477df919791427"
qinput = "Estado de Mexico"
inputtype = "textquery"

params1 = {
    "input" : qinput,
    "inputtype" : inputtype,
    #"id": g_id,
    #"place_id": place_id,
    #"location" : target_coordinates,
    #"keyword" : target_search,
    #"radius" : target_radius,
    #"type" : target_type,
    "key": gkey
}

params2 = {
    "query" : target_query,
    "place_id": place_id,
    #"keyword" : target_search,
    #"radius" : target_radius,
    #"type" : target_type,
    "key": gkey
    #"address" : target_address
}

params3 = {
    #"query" : target_query,
    #"location" : target_coordinates,
    #"keyword" : target_search,
    #"radius" : target_radius,
    #"type" : target_type,
    "key": gkey,
    "address" : target_address
}

params4 = {
    "input" : qinput,
    "inputtype" : inputtype,
    #"id": g_id,
    #"place_id": place_id,
    #"location" : target_coordinates,
    #"keyword" : target_search,
    #"radius" : target_radius,
    #"type" : target_type,
    "key": gkey
}

response1 = requests.get(base_url, params=params1)
response2 = requests.get(details_url, params=params2)
response3 = requests.get(geo_url, params=params3)
response4 = requests.get(place_from_text, params=params4)

# %%
print(response1.url)
print(response2.url)
print(response3.url)
print(response4.url)
# Out:
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?input=Estado+de+Mexico&inputtype=textquery&key=AIzaSyAwDyEwcf_ffX0otnRMJYklewZ9ywIkxJc
# https://maps.googleapis.com/maps/api/place/details/json?query=Estado+de+Mexico&place_id=ChIJOwrrwJKJzYURV6jFn775_sI&key=AIzaSyAwDyEwcf_ffX0otnRMJYklewZ9ywIkxJc
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAwDyEwcf_ffX0otnRMJYklewZ9ywIkxJc&address=Estado+de+Mexico
# https://maps.googleapis.com/maps/api/place/findplacefromtext/json?input=Estado+de+Mexico&inputtype=textquery&key=AIzaSyAwDyEwcf_ffX0otnRMJYklewZ9ywIkxJc

# %%
 # convert response to json
places_data = response4.json()

# Print the json (pretty printed)
print(json.dumps(places_data, indent=4, sort_keys=True))
# Out:
# {
#     "candidates": [
#         {
#             "place_id": "ChIJOwrrwJKJzYURV6jFn775_sI"
#         }
#     ],
#     "status": "OK"
# }

# %%
DENUE_df = pd.read_csv("Resources/DENUE_Filtered_complete.csv")
DENUE_df
# Out:
#        Unnamed: 0       ID                      Nombre de la Unidad Económica  \
# 0          485138  2014798                                MICHELADAS 6 GRADOS
# 1          180862  6354673            MEGA COMERCIAL MEXICANA ALAMEDAS SUC 23
# 2          311724  2363453                     TIENDA DE ABARROTES SIN NOMBRE
# 3           52732  2343091                          MAQUINAS PARA SERIGRAFÃA
# 4          452328  2020353                     ANTOJITOS MEXICANOS SIN NOMBRE
# ...           ...      ...                                                ...
# 72665      287589  2451555                             RECAUDERÃA SIN NOMBRE
# 72666      550479  2187493  LA IGLESIA DE JESUCRISTO DE LOS SANTOS DE LOS ...
# 72667       88996  2077986                         ABARROTES Y CREMERÃA CECI
# 72668      226940  2154985                   MUEBLERÃA LA RIVERA DE VERACRUZ
# 72669      399610  2275353                         INTERNET SHOGAI BUISUGANAI
#
#                                             Razón social  \
# 0                                                    NaN
# 1               TIENDAS COMERCIAL MEXICANA  S.A. DE C.V.
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 72665                                                NaN
# 72666  LA IGLESIA DE JESUCRISTO DE LOS SANTOS DE LOS ...
# 72667                                                NaN
# 72668                                                NaN
# 72669                                                NaN
#
#        Código de la clase de actividad SCIAN  \
# 0                                     722412
# 1                                     462111
# 2                                     461110
# 3                                     333245
# 4                                     722513
# ...                                      ...
# 72665                                 461130
# 72666                                 813210
# 72667                                 461110
# 72668                                 466111
# 72669                                 561432
#
#                          Nombre de clase de la actividad  \
# 0                            Bares, cantinas y similares
# 1                 Comercio al por menor en supermercados
# 2      Comercio al por menor en tiendas de abarrotes,...
# 3      FabricaciÃ³n de maquinaria y equipo para la in...
# 4      Restaurantes con servicio de preparaciÃ³n de a...
# ...                                                  ...
# 72665  Comercio al por menor de frutas y verduras fre...
# 72666           Asociaciones y organizaciones religiosas
# 72667  Comercio al por menor en tiendas de abarrotes,...
# 72668     Comercio al por menor de muebles para el hogar
# 72669                 Servicios de acceso a computadoras
#
#       Descripcion estrato personal ocupado Tipo de vialidad  \
# 0                          6 a 10 personas            CALLE
# 1                       101 a 250 personas            CALLE
# 2                           0 a 5 personas          AVENIDA
# 3                           0 a 5 personas            CALLE
# 4                           0 a 5 personas            CALLE
# ...                                    ...              ...
# 72665                       0 a 5 personas          CALZADA
# 72666                   101 a 250 personas          AVENIDA
# 72667                       0 a 5 personas            CALLE
# 72668                       0 a 5 personas          AVENIDA
# 72669                       0 a 5 personas            CALLE
#
#             Nombre de la vialidad Tipo de entre vialidad 1  ...  \
# 0      AVENIDA VALLE DEL YANG-TSE                    CALLE  ...
# 1            ADOLFO LÃPEZ MATEOS                    CALLE  ...
# 2                         JUÃREZ                    CALLE  ...
# 3                        MAYAQUEN                  AVENIDA  ...
# 4                      GUANAJUATO                    CALLE  ...
# ...                           ...                      ...  ...
# 72665                DEL PANTEÃN                  PRIVADA  ...
# 72666                     TEXCOCO                    CALLE  ...
# 72667               VALLE PERDIDO                  ANDADOR  ...
# 72668                 CUAUHTÃMOC                    CALLE  ...
# 72669                    EL PATIO                    CALLE  ...
#
#                     Localidad Área geoestadística básica  Manzana  \
# 0      CIUDAD NEZAHUALCÃYOTL                          30       6
# 1        CIUDAD LÃPEZ MATEOS                         202      17
# 2       RÃO FRÃO DE JUÃREZ                         834       2
# 3               CHIMALHUACÃN                        008A      58
# 4         ECATEPEC DE MORELOS                        320A      17
# ...                       ...                         ...     ...
# 72665        SAN MATEO ATENCO                         359      15
# 72666  CIUDAD NEZAHUALCÃYOTL                        1310      13
# 72667     ECATEPEC DE MORELOS                        2860      25
# 72668              IXTAPALUCA                        1071      14
# 72669       FUENTES DEL VALLE                        1114       2
#
#       NÃºmero de telÃ©fono    Correo electrÃ³nico  \
# 0                      NaN                    NaN
# 1                      NaN  MMUNOZ@COMERCI.COM.MX
# 2                      NaN                    NaN
# 3             5.522284e+09                    NaN
# 4                      NaN                    NaN
# ...                    ...                    ...
# 72665                  NaN                    NaN
# 72666                  NaN                    NaN
# 72667         5.557129e+09                    NaN
# 72668         5.559763e+09                    NaN
# 72669                  NaN                    NaN
#
#                   Sitio en Internet Tipo de establecimiento    Latitud  \
# 0                               NaN                    Fijo  19.492879
# 1      WWW.COMERCIALMEXICANA.COM.MX                    Fijo  19.552485
# 2                               NaN                    Fijo  19.355595
# 3                               NaN                    Fijo  19.432340
# 4                               NaN                    Fijo  19.507917
# ...                             ...                     ...        ...
# 72665                           NaN                    Fijo  19.267672
# 72666                           NaN                    Fijo  19.377524
# 72667                           NaN                    Fijo  19.507421
# 72668                           NaN                    Fijo  19.309784
# 72669                           NaN                    Fijo  19.634752
#
#         Longitud  Fecha de incorporación al DENUE
# 0     -99.059727                           jul-10
# 1     -99.241193                           jul-10
# 2     -98.672878                           dic-14
# 3     -98.974542                           dic-14
# 4     -99.028781                           jul-10
# ...          ...                              ...
# 72665 -99.537364                           dic-14
# 72666 -99.008693                           jul-10
# 72667 -99.043806                           jul-10
# 72668 -98.913128                           jul-10
# 72669 -99.129270                           dic-14
#
# [72670 rows x 42 columns]

# %%
#fig = gmaps.figure()

#path =  {"geometry": {
#           "bounds": {
#               "northeast": {
#                   "lat": 20.2858665,
#                   "lng": -98.5968666
#               },
#               "southwest": {
#                   "lat": 18.3669428,
#                   "lng": -100.6130911
#               }
#           },
#       "location": {
#           "lat": 19.4968732,
#           "lng": -99.72326729999999
#       },
#       "location_type": "APPROXIMATE",
#       "viewport": {
#           "northeast": {
#           "lat": 20.2858665,
#           "lng": -98.5968666
#       },
#           "southwest": {
#           "lat": 18.3669428,
#           "lng": -100.6130911
#           }
#       }
#       }}
#path = [{"lat": 20.2858665,
#        "lng": -98.5968666}
#      {"lat": 18.3669428,
#       "lng": -100.6130911},
#      {"lat": 19.4968732,
#       "lng": -99.72326729999999}]
    
#gmaps.Polygon(path)
#paths
list(DENUE_df["Descripcion estrato personal ocupado"].unique())
# Out:
# ['6 a 10 personas',
#  '101 a 250 personas',
#  '0 a 5 personas',
#  '11 a 30 personas',
#  '51 a 100 personas',
#  '251 y mÃ¡s personas',
#  '31 a 50 personas']

# %%
#micro=DENUE_df.loc[DENUE_df["Descripcion estrato personal ocupado"]]

Size_dict={'0 a 5 personas':1,
           '6 a 10 personas':2,
           '11 a 30 personas':3,
           "31 a 50 personas":4,
           '51 a 100 personas':5,
           '101 a 250 personas':6,
           '251 y más personas':7}
Size_dict2={'0 a 5 personas':"Micro",
           '6 a 10 personas':"Micro",
           '11 a 30 personas':"Pequeña",
           "31 a 50 personas":"Pequeña",
           '51 a 100 personas':"Mediana",
           '101 a 250 personas':"Mediana",
           '251 y más personas':"Grande"}

DENUE_df["Company Size"]=DENUE_df["Descripcion estrato personal ocupado"].astype(str)
DENUE_df["Company Size (int)"]=DENUE_df["Descripcion estrato personal ocupado"].astype(str)
DENUE_df=DENUE_df.replace({"Company Size (int)": Size_dict})
DENUE_df=DENUE_df.replace({"Company Size": Size_dict2})

#DENUE_df["Company Size"] = 
#DENUE_df["Company Size"]=DENUE_df["Descripcion estrato personal ocupado"].replace(['0 a 5 personas','6 a 10 personas'],[1])
                        # DENUE_df["Descripcion estrato personal ocupado"].replace(['11 a 30 personas','31 a 50 personas'],[2])
                         #DENUE_df["Descripcion estrato personal ocupado"].replace(['51 a 100 personas','101 a 250 personas','251 y más personas'],[3])
    #{"Descripcion estrato personal ocupado": Size_dict})
#rating

#rating = DENUE_df["Descripcion estrato personal ocupado"][Size_dict]

DENUE_df
# Out:
#        Unnamed: 0       ID                      Nombre de la Unidad Económica  \
# 0          485138  2014798                                MICHELADAS 6 GRADOS
# 1          180862  6354673            MEGA COMERCIAL MEXICANA ALAMEDAS SUC 23
# 2          311724  2363453                     TIENDA DE ABARROTES SIN NOMBRE
# 3           52732  2343091                          MAQUINAS PARA SERIGRAFÃA
# 4          452328  2020353                     ANTOJITOS MEXICANOS SIN NOMBRE
# ...           ...      ...                                                ...
# 72665      287589  2451555                             RECAUDERÃA SIN NOMBRE
# 72666      550479  2187493  LA IGLESIA DE JESUCRISTO DE LOS SANTOS DE LOS ...
# 72667       88996  2077986                         ABARROTES Y CREMERÃA CECI
# 72668      226940  2154985                   MUEBLERÃA LA RIVERA DE VERACRUZ
# 72669      399610  2275353                         INTERNET SHOGAI BUISUGANAI
#
#                                             Razón social  \
# 0                                                    NaN
# 1               TIENDAS COMERCIAL MEXICANA  S.A. DE C.V.
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 72665                                                NaN
# 72666  LA IGLESIA DE JESUCRISTO DE LOS SANTOS DE LOS ...
# 72667                                                NaN
# 72668                                                NaN
# 72669                                                NaN
#
#        Código de la clase de actividad SCIAN  \
# 0                                     722412
# 1                                     462111
# 2                                     461110
# 3                                     333245
# 4                                     722513
# ...                                      ...
# 72665                                 461130
# 72666                                 813210
# 72667                                 461110
# 72668                                 466111
# 72669                                 561432
#
#                          Nombre de clase de la actividad  \
# 0                            Bares, cantinas y similares
# 1                 Comercio al por menor en supermercados
# 2      Comercio al por menor en tiendas de abarrotes,...
# 3      FabricaciÃ³n de maquinaria y equipo para la in...
# 4      Restaurantes con servicio de preparaciÃ³n de a...
# ...                                                  ...
# 72665  Comercio al por menor de frutas y verduras fre...
# 72666           Asociaciones y organizaciones religiosas
# 72667  Comercio al por menor en tiendas de abarrotes,...
# 72668     Comercio al por menor de muebles para el hogar
# 72669                 Servicios de acceso a computadoras
#
#       Descripcion estrato personal ocupado Tipo de vialidad  \
# 0                          6 a 10 personas            CALLE
# 1                       101 a 250 personas            CALLE
# 2                           0 a 5 personas          AVENIDA
# 3                           0 a 5 personas            CALLE
# 4                           0 a 5 personas            CALLE
# ...                                    ...              ...
# 72665                       0 a 5 personas          CALZADA
# 72666                   101 a 250 personas          AVENIDA
# 72667                       0 a 5 personas            CALLE
# 72668                       0 a 5 personas          AVENIDA
# 72669                       0 a 5 personas            CALLE
#
#             Nombre de la vialidad Tipo de entre vialidad 1  ... Manzana  \
# 0      AVENIDA VALLE DEL YANG-TSE                    CALLE  ...       6
# 1            ADOLFO LÃPEZ MATEOS                    CALLE  ...      17
# 2                         JUÃREZ                    CALLE  ...       2
# 3                        MAYAQUEN                  AVENIDA  ...      58
# 4                      GUANAJUATO                    CALLE  ...      17
# ...                           ...                      ...  ...     ...
# 72665                DEL PANTEÃN                  PRIVADA  ...      15
# 72666                     TEXCOCO                    CALLE  ...      13
# 72667               VALLE PERDIDO                  ANDADOR  ...      25
# 72668                 CUAUHTÃMOC                    CALLE  ...      14
# 72669                    EL PATIO                    CALLE  ...       2
#
#       NÃºmero de telÃ©fono    Correo electrÃ³nico  \
# 0                      NaN                    NaN
# 1                      NaN  MMUNOZ@COMERCI.COM.MX
# 2                      NaN                    NaN
# 3             5.522284e+09                    NaN
# 4                      NaN                    NaN
# ...                    ...                    ...
# 72665                  NaN                    NaN
# 72666                  NaN                    NaN
# 72667         5.557129e+09                    NaN
# 72668         5.559763e+09                    NaN
# 72669                  NaN                    NaN
#
#                   Sitio en Internet Tipo de establecimiento    Latitud  \
# 0                               NaN                    Fijo  19.492879
# 1      WWW.COMERCIALMEXICANA.COM.MX                    Fijo  19.552485
# 2                               NaN                    Fijo  19.355595
# 3                               NaN                    Fijo  19.432340
# 4                               NaN                    Fijo  19.507917
# ...                             ...                     ...        ...
# 72665                           NaN                    Fijo  19.267672
# 72666                           NaN                    Fijo  19.377524
# 72667                           NaN                    Fijo  19.507421
# 72668                           NaN                    Fijo  19.309784
# 72669                           NaN                    Fijo  19.634752
#
#         Longitud Fecha de incorporación al DENUE Company Size  \
# 0     -99.059727                          jul-10        Micro
# 1     -99.241193                          jul-10      Mediana
# 2     -98.672878                          dic-14        Micro
# 3     -98.974542                          dic-14        Micro
# 4     -99.028781                          jul-10        Micro
# ...          ...                             ...          ...
# 72665 -99.537364                          dic-14        Micro
# 72666 -99.008693                          jul-10      Mediana
# 72667 -99.043806                          jul-10        Micro
# 72668 -98.913128                          jul-10        Micro
# 72669 -99.129270                          dic-14        Micro
#
#        Company Size (int)
# 0                       2
# 1                       6
# 2                       1
# 3                       1
# 4                       1
# ...                   ...
# 72665                   1
# 72666                   6
# 72667                   1
# 72668                   1
# 72669                   1
#
# [72670 rows x 44 columns]

# %%
#DENUE_df.loc[DENUE_df["Descripcion estrato personal ocupado"].isin(['0 a 5 personas']),'Company size']=1.0
#DENUE_df.loc[DENUE_df["Descripcion estrato personal ocupado"].isin(['6 a 10 personas']),'Company size']=2.0
#DENUE_df.loc[DENUE_df["Descripcion estrato personal ocupado"].isin(['11 a 30 personas']),'Company size']=3.0
#DENUE_df.loc[DENUE_df["Descripcion estrato personal ocupado"].isin(['31 a 50 personas']),'Company size']=4.0
#DENUE_df.loc[DENUE_df["Descripcion estrato personal ocupado"].isin(['51 a 100 personas']),'Company size']=5.0
#DENUE_df.loc[DENUE_df["Descripcion estrato personal ocupado"].isin(['101 a 250 personas']),'Company size']=6.0
#DENUE_df.loc[DENUE_df["Descripcion estrato personal ocupado"].isin(['251 y mÃ¡s personas']),'Company size']=7.0
#DENUE_df.head()

# %%
Micro_df = DENUE_df.loc[DENUE_df["Company Size"]=="Micro"]
locations_Micro = Micro_df[["Latitud", "Longitud"]]
# Fill NaN values and convert to float
rating_Micro = Micro_df["Company Size (int)"]#.astype(float)
rating_Medium = Medium_df["Company Size (int)"]

Medium_df = DENUE_df.loc[DENUE_df["Company Size"]=="Mediana"]
locations_Medium = Medium_df[["Latitud", "Longitud"]]








# Plot Heatmap
fig = gmaps.figure()

# Create layers
#symbols = gmaps.symbol_layer(locations, fill_color='red', stroke_color='red')
heat_layer = gmaps.heatmap_layer(locations_Micro, weights=rating_Micro, 
                                 dissipating=False, max_intensity=50,
                                 point_radius=0.005,gradient = [(0,0,0,0),"gray","black"])

heat_layer2 = gmaps.heatmap_layer(locations_Medium, weights=rating_Medium, 
                                 dissipating=False, max_intensity=50,
                                 point_radius=0.005,gradient = [(0,0,0,0),"aqua","blue"])
# Add layer
fig.add_layer(heat_layer)
fig.add_layer(heat_layer2)
#fig.add_layer(symbols)
# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
