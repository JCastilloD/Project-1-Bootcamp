# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

# Import API key
from config import inegi_key #inegi token
from config import coneval_key #coneval
from config import gkey #google key

# %%
#url = "https://www.inegi.org.mx/app/api/denue/v1/consulta/BuscarAreaActEstr"
#declare parameters

#EntFed = "15" #entidad federativa
#Mpo    = "0" #municipio dentro de la entidad federativa
#Loc    = "0" #loc dentro del mpo
#AGEB   = "0" #AGEB no sé que es AGEB
#Mnz    = "0" #manzana tres dígitos
#Sector = "0" # Sector de la actividad económica (ej. 46 )
#Subsec = "0" # Subsector de la actividad económica (ej. 464 )
#Rama   = "0" #Rama de la actividad económica (ej. 4641)
#Clase  = "0" #Clase de la actividad económica (ej. 464112)
#Nomest = "0" # Nombre del establecimiento
#Regini = "1" #Número de registro a partir del cuál se mostrarán los resultados de la búsqueda. 
#Regfin = "25" #Número de registro final que se mostrará en resultados de la búsqueda. 
#Id     = "0" #Clave única del establecimiento.
#Estr   = "0" # Clave de un dígito del estrato. Para incluir todos los tamaños se especifica 0.
                #1. Para incluir de 0 a 5 personas.
                #2. Para incluir de 6 a 10 personas.
                #3. Para incluir de 11 a 30 personas.
                #4. Para incluir de 31 a 50 personas.
                #5. Para incluir de 51 a 100 personas.
                #6. Para incluir de 101 a 250 personas.
                #7. Para incluir de 251 y más person

#Ejemplo
#https://www.inegi.org.mx/app/api/denue/v1/consulta/BuscarAreaActEstr/01/0/0/0/0/0/0/0/0/oxxo/1/15/0/1/[Aquí va tu token]
#https://www.inegi.org.mx/app/api/denue/v1/consulta/BuscarAreaActEstr/01/0/0/0/0/0/0/0/0/oxxo/1/15/0/1/[8455939b-9726-bb8c-c70d-681609b40110]
#https://www.inegi.org.mx/app/api/denue/v1/consulta/BuscarAreaActEstr/01/0/0/0/0/0/0/0/0/oxxo/1/15/0/1/[5537bc61-be6f-dddf-a592-e3cd4417e515]


#urlconsulta = url + "/" + EntFed + "/" + Mpo + "/" + Loc + "/" + AGEB + "/" + Mnz + "/" + Sector + "/" + Subsec + "/" + Rama + "/" + Clase + "/" + Nomest + "/" + Regini + "/" + Regfin + "/" + Id + "/" + Estr + "/" + "[" + inegi_key + "]"

#print(urlconsulta)
#print(inegi_key)

# %%
#This code was designed to do an exploratory analysis of the data
# and get a sense of the values of each variables, filter them and standardize them 

denue_df = pd.read_csv("Resources/DENUE_sample.csv",encoding="ISO-8859-1")
#denue_df = pd.read_csv("Resources/DENUE_full_data_old.csv",encoding="ISO-8859-1")
denue_df
# Out:
#        Unnamed: 0       ID     Nombre de la Unidad Económica Razón social  \
# 0          174704  2511586         LONJA MERCANTIL HERNANDEZ          NaN
# 1          540472  2363713          ESTÃÂTICA UNISEX DIANA          NaN
# 2           23013  2032449                TORTILLERÃÂA 599          NaN
# 3           86301  2002299              ABARROTES SIN NOMBRE          NaN
# 4          399216  2249276                      INTERNET MIP          NaN
# ...           ...      ...                               ...          ...
# 72665      534754  2505632                 ESTÃÂTICA PLAZA          NaN
# 72666      407809  2018895        ESCUELA PRIMARIA 5 DE MAYO          NaN
# 72667      186032  2544866             MISCELÃÂNEA ALVAREZ          NaN
# 72668      207159  2373840  MISCELÃÂNEA LOS TRES ANGELITOS          NaN
# 72669      400987  2549759                             KRASH          NaN
#
#        Código de la clase de actividad SCIAN  \
# 0                                     461110
# 1                                     812110
# 2                                     311830
# 3                                     461110
# 4                                     561432
# ...                                      ...
# 72665                                 812110
# 72666                                 611122
# 72667                                 461110
# 72668                                 461110
# 72669                                 561432
#
#                          Nombre de clase de la actividad  \
# 0      Comercio al por menor en tiendas de abarrotes,...
# 1      Salones y clÃÂ­nicas de belleza y peluquerÃÂ­as
# 2      ElaboraciÃÂ³n de tortillas de maÃÂ­z y molie...
# 3      Comercio al por menor en tiendas de abarrotes,...
# 4                     Servicios de acceso a computadoras
# ...                                                  ...
# 72665  Salones y clÃÂ­nicas de belleza y peluquerÃÂ­as
# 72666  Escuelas de educaciÃÂ³n primaria del sector p...
# 72667  Comercio al por menor en tiendas de abarrotes,...
# 72668  Comercio al por menor en tiendas de abarrotes,...
# 72669                 Servicios de acceso a computadoras
#
#       Descripcion estrato personal ocupado Tipo de vialidad  \
# 0                           0 a 5 personas            CALLE
# 1                           0 a 5 personas            CALLE
# 2                           0 a 5 personas            CALLE
# 3                           0 a 5 personas          AVENIDA
# 4                           0 a 5 personas            CALLE
# ...                                    ...              ...
# 72665                       0 a 5 personas            CALLE
# 72666                      6 a 10 personas            CALLE
# 72667                       0 a 5 personas            CALLE
# 72668                       0 a 5 personas            CALLE
# 72669                       0 a 5 personas            CALLE
#
#                Nombre de la vialidad Tipo de entre vialidad 1  ...  \
# 0                   NICOLÃÂS BRAVO                    CALLE  ...
# 1                FRANCISCO I. MADERO                  AVENIDA  ...
# 2               AVENIDA SAN ÃÂNGEL                    CALLE  ...
# 3                 PROGRESO MUNICIPAL                  PRIVADA  ...
# 4      ZUMPANGO-REYES KILÃÂMETRO 9                    CALLE  ...
# ...                              ...                      ...  ...
# 72665        GENERAL VICENTE VILLADA                    CALLE  ...
# 72666                         SUR 10                    CALLE  ...
# 72667               IGNACIO ZARAGOZA                    CALLE  ...
# 72668                        GIRASOL                  AVENIDA  ...
# 72669                        NINGUNO                    CALLE  ...
#
#                            Localidad Área geoestadí­stica básica  Manzana  \
# 0       SAN BARTOLOMÃÂ ATLATLAHUCA                          216       4
# 1                         IXTAPALUCA                          904      12
# 2           CIUDAD NEZAHUALCÃÂYOTL                         1289       5
# 3                           TULTEPEC                          335       8
# 4                   SAN SEBASTIÃÂN                          359      16
# ...                              ...                          ...     ...
# 72665                        METEPEC                          563      16
# 72666            ECATEPEC DE MORELOS                          741      19
# 72667                  XONACATLÃÂN                           43      24
# 72668  CHALCO DE DÃÂAZ COVARRUBIAS                         081A      29
# 72669           SAN MARCOS TLAZALPAN                          110      28
#
#       NÃÂºmero de telÃÂ©fono   Correo electrÃÂ³nico  Sitio en Internet  \
# 0                 7.171710e+09                     NaN                NaN
# 1                          NaN                     NaN                NaN
# 2                          NaN                     NaN                NaN
# 3                          NaN                     NaN                NaN
# 4                          NaN                     NaN                NaN
# ...                        ...                     ...                ...
# 72665             7.222082e+09  FROLOPZ31@YAHOO.COM.MX                NaN
# 72666             5.557887e+09                     NaN                NaN
# 72667                      NaN                     NaN                NaN
# 72668                      NaN                     NaN                NaN
# 72669                      NaN                     NaN                NaN
#
#       Tipo de establecimiento    Latitud   Longitud  \
# 0                        Fijo  19.069133 -99.611156
# 1                        Fijo  19.290680 -98.902444
# 2                        Fijo  19.389040 -99.015859
# 3                        Fijo  19.680749 -99.136141
# 4                        Fijo  19.787891 -99.055222
# ...                       ...        ...        ...
# 72665                    Fijo  19.252294 -99.604720
# 72666                    Fijo  19.529771 -99.045686
# 72667                    Fijo  19.412025 -99.522470
# 72668                    Fijo  19.263108 -98.911619
# 72669                    Fijo  19.806111 -99.717500
#
#        Fecha de incorporación al DENUE
# 0                               jul-10
# 1                               dic-14
# 2                               dic-14
# 3                               jul-10
# 4                               dic-14
# ...                                ...
# 72665                           jul-10
# 72666                           jul-10
# 72667                           jul-10
# 72668                           dic-14
# 72669                           jul-10
#
# [72670 rows x 42 columns]

# %%
list(denue_df)
# Out:
# ['Unnamed: 0',
#  'ID',
#  'Nombre de la Unidad Económica',
#  'Razón social',
#  'Código de la clase de actividad SCIAN',
#  'Nombre de clase de la actividad',
#  'Descripcion estrato personal ocupado',
#  'Tipo de vialidad',
#  'Nombre de la vialidad',
#  'Tipo de entre vialidad 1',
#  'Nombre de entre vialidad 1',
#  'Tipo de entre vialidad 2',
#  'Nombre de entre vialidad 2',
#  'Tipo de entre vialidad 3',
#  'Nombre de entre vialidad 3',
#  'NÃ\x83Âºmero exterior o kilÃ\x83Â³metro',
#  'Letra exterior',
#  'Edificio',
#  'Edificio Piso',
#  'NÃ\x83Âºmero interior',
#  'Letra interior',
#  'Tipo de asentamiento humano',
#  'Nombre de asentamiento humano',
#  'Tipo centro comercial',
#  'Corredor industrial, centro comercial o mercado público',
#  'NÃ\x83Âºmero de local',
#  'Código Postal',
#  'Clave entidad',
#  'Entidad federativa',
#  'Clave municipio',
#  'Municipio',
#  'Clave localidad',
#  'Localidad',
#  'Área geoestadí\xadstica básica ',
#  'Manzana',
#  'NÃ\x83Âºmero de telÃ\x83Â©fono',
#  'Correo electrÃ\x83Â³nico',
#  'Sitio en Internet',
#  'Tipo de establecimiento',
#  'Latitud',
#  'Longitud',
#  'Fecha de incorporación al DENUE']

# %%
denue_df["Código de la clase de actividad SCIAN"].astype(str).str[:2].astype(int)
denue_df.insert(1, 'Código Tipo de Industria', denue_df["Código de la clase de actividad SCIAN"].astype(str).str[:2].astype(int))
denue_df
# Out:
#        Unnamed: 0  Código Tipo de Industria       ID  \
# 0          174704                        46  2511586
# 1          540472                        81  2363713
# 2           23013                        31  2032449
# 3           86301                        46  2002299
# 4          399216                        56  2249276
# ...           ...                       ...      ...
# 72665      534754                        81  2505632
# 72666      407809                        61  2018895
# 72667      186032                        46  2544866
# 72668      207159                        46  2373840
# 72669      400987                        56  2549759
#
#           Nombre de la Unidad Económica Razón social  \
# 0             LONJA MERCANTIL HERNANDEZ          NaN
# 1              ESTÃÂTICA UNISEX DIANA          NaN
# 2                    TORTILLERÃÂA 599          NaN
# 3                  ABARROTES SIN NOMBRE          NaN
# 4                          INTERNET MIP          NaN
# ...                                 ...          ...
# 72665                 ESTÃÂTICA PLAZA          NaN
# 72666        ESCUELA PRIMARIA 5 DE MAYO          NaN
# 72667             MISCELÃÂNEA ALVAREZ          NaN
# 72668  MISCELÃÂNEA LOS TRES ANGELITOS          NaN
# 72669                             KRASH          NaN
#
#        Código de la clase de actividad SCIAN  \
# 0                                     461110
# 1                                     812110
# 2                                     311830
# 3                                     461110
# 4                                     561432
# ...                                      ...
# 72665                                 812110
# 72666                                 611122
# 72667                                 461110
# 72668                                 461110
# 72669                                 561432
#
#                          Nombre de clase de la actividad  \
# 0      Comercio al por menor en tiendas de abarrotes,...
# 1      Salones y clÃÂ­nicas de belleza y peluquerÃÂ­as
# 2      ElaboraciÃÂ³n de tortillas de maÃÂ­z y molie...
# 3      Comercio al por menor en tiendas de abarrotes,...
# 4                     Servicios de acceso a computadoras
# ...                                                  ...
# 72665  Salones y clÃÂ­nicas de belleza y peluquerÃÂ­as
# 72666  Escuelas de educaciÃÂ³n primaria del sector p...
# 72667  Comercio al por menor en tiendas de abarrotes,...
# 72668  Comercio al por menor en tiendas de abarrotes,...
# 72669                 Servicios de acceso a computadoras
#
#       Descripcion estrato personal ocupado Tipo de vialidad  \
# 0                           0 a 5 personas            CALLE
# 1                           0 a 5 personas            CALLE
# 2                           0 a 5 personas            CALLE
# 3                           0 a 5 personas          AVENIDA
# 4                           0 a 5 personas            CALLE
# ...                                    ...              ...
# 72665                       0 a 5 personas            CALLE
# 72666                      6 a 10 personas            CALLE
# 72667                       0 a 5 personas            CALLE
# 72668                       0 a 5 personas            CALLE
# 72669                       0 a 5 personas            CALLE
#
#                Nombre de la vialidad  ...                      Localidad  \
# 0                   NICOLÃÂS BRAVO  ...   SAN BARTOLOMÃÂ ATLATLAHUCA
# 1                FRANCISCO I. MADERO  ...                     IXTAPALUCA
# 2               AVENIDA SAN ÃÂNGEL  ...       CIUDAD NEZAHUALCÃÂYOTL
# 3                 PROGRESO MUNICIPAL  ...                       TULTEPEC
# 4      ZUMPANGO-REYES KILÃÂMETRO 9  ...               SAN SEBASTIÃÂN
# ...                              ...  ...                            ...
# 72665        GENERAL VICENTE VILLADA  ...                        METEPEC
# 72666                         SUR 10  ...            ECATEPEC DE MORELOS
# 72667               IGNACIO ZARAGOZA  ...                  XONACATLÃÂN
# 72668                        GIRASOL  ...  CHALCO DE DÃÂAZ COVARRUBIAS
# 72669                        NINGUNO  ...           SAN MARCOS TLAZALPAN
#
#       Área geoestadí­stica básica  Manzana NÃÂºmero de telÃÂ©fono  \
# 0                              216       4             7.171710e+09
# 1                              904      12                      NaN
# 2                             1289       5                      NaN
# 3                              335       8                      NaN
# 4                              359      16                      NaN
# ...                            ...     ...                      ...
# 72665                          563      16             7.222082e+09
# 72666                          741      19             5.557887e+09
# 72667                           43      24                      NaN
# 72668                         081A      29                      NaN
# 72669                          110      28                      NaN
#
#         Correo electrÃÂ³nico Sitio en Internet  Tipo de establecimiento  \
# 0                         NaN               NaN                     Fijo
# 1                         NaN               NaN                     Fijo
# 2                         NaN               NaN                     Fijo
# 3                         NaN               NaN                     Fijo
# 4                         NaN               NaN                     Fijo
# ...                       ...               ...                      ...
# 72665  FROLOPZ31@YAHOO.COM.MX               NaN                     Fijo
# 72666                     NaN               NaN                     Fijo
# 72667                     NaN               NaN                     Fijo
# 72668                     NaN               NaN                     Fijo
# 72669                     NaN               NaN                     Fijo
#
#          Latitud   Longitud Fecha de incorporación al DENUE
# 0      19.069133 -99.611156                          jul-10
# 1      19.290680 -98.902444                          dic-14
# 2      19.389040 -99.015859                          dic-14
# 3      19.680749 -99.136141                          jul-10
# 4      19.787891 -99.055222                          dic-14
# ...          ...        ...                             ...
# 72665  19.252294 -99.604720                          jul-10
# 72666  19.529771 -99.045686                          jul-10
# 72667  19.412025 -99.522470                          jul-10
# 72668  19.263108 -98.911619                          dic-14
# 72669  19.806111 -99.717500                          jul-10
#
# [72670 rows x 43 columns]

# %%
denue_df.to_csv("Output/DENUE_Filtered.csv", index=True, header=True)

# %%
zip_df = pd.read_csv("Resources/Codigospostales.csv",encoding="ISO-8859-1")
zip_df = zip_df.iloc[0:8127,:]
zip_df
# Out:
#       d_codigo                d_asenta d_tipo_asenta         D_mnpio d_estado  \
# 0      50000.0                  Centro       Colonia          Toluca   México
# 1      50010.0                Celanese       Colonia          Toluca   México
# 2      50010.0             Club Jardín       Colonia          Toluca   México
# 3      50010.0               Guadalupe       Colonia          Toluca   México
# 4      50010.0         La Cruz Comalco       Colonia          Toluca   México
# ...        ...                     ...           ...             ...      ...
# 8122   57910.0    Constitución de 1857       Colonia  Nezahualcóyotl   México
# 8123   57920.0            Santa Martha       Colonia  Nezahualcóyotl   México
# 8124   57930.0             Manantiales       Colonia  Nezahualcóyotl   México
# 8125   57940.0             Loma Bonita       Colonia  Nezahualcóyotl   México
# 8126   57950.0  Ampliación Las Águilas       Colonia  Nezahualcóyotl   México
#
#                    d_ciudad     d_CP  c_estado  c_oficina  c_CP  \
# 0           Toluca de Lerdo  50091.0      15.0    50091.0   NaN
# 1           Toluca de Lerdo  50091.0      15.0    50091.0   NaN
# 2           Toluca de Lerdo  50091.0      15.0    50091.0   NaN
# 3           Toluca de Lerdo  50091.0      15.0    50091.0   NaN
# 4           Toluca de Lerdo  50091.0      15.0    50091.0   NaN
# ...                     ...      ...       ...        ...   ...
# 8122  Ciudad Nezahualcóyotl  57002.0      15.0    57002.0   NaN
# 8123  Ciudad Nezahualcóyotl  57002.0      15.0    57002.0   NaN
# 8124  Ciudad Nezahualcóyotl  57002.0      15.0    57002.0   NaN
# 8125  Ciudad Nezahualcóyotl  57002.0      15.0    57002.0   NaN
# 8126  Ciudad Nezahualcóyotl  57002.0      15.0    57002.0   NaN
#
#       c_tipo_asenta  c_mnpio  id_asenta_cpcons  d_zona  c_cve_ciudad
# 0               9.0    106.0             160.0  Urbano          20.0
# 1               9.0    106.0             163.0  Urbano          20.0
# 2               9.0    106.0             164.0  Urbano          20.0
# 3               9.0    106.0             165.0  Urbano          20.0
# 4               9.0    106.0             166.0  Urbano          20.0
# ...             ...      ...               ...     ...           ...
# 8122            9.0     58.0            4641.0  Urbano          10.0
# 8123            9.0     58.0            4642.0  Urbano          10.0
# 8124            9.0     58.0            4643.0  Urbano          10.0
# 8125            9.0     58.0            4645.0  Urbano          10.0
# 8126            9.0     58.0            4646.0  Urbano          10.0
#
# [8127 rows x 15 columns]

# %%
list(zip_df["d_tipo_asenta"].unique())
# Out:
# ['Colonia',
#  'Fraccionamiento',
#  'Barrio',
#  'Unidad habitacional',
#  'Zona industrial',
#  'Residencial',
#  'Pueblo',
#  'Gran usuario',
#  'Zona federal',
#  'Conjunto habitacional',
#  'Ejido',
#  'Aeropuerto',
#  'Ranchería',
#  'Rancho',
#  'Parque industrial',
#  'Paraje',
#  'Hacienda',
#  'Equipamiento',
#  'Exhacienda',
#  'Condominio',
#  'Zona comercial',
#  'Campamento',
#  'Granja',
#  'Villa',
#  'Zona militar']

# %%
list(denue_df["Tipo de asentamiento humano"].unique())
# Out:
# ['PUEBLO',
#  'COLONIA',
#  'BARRIO',
#  'CONJUNTO HABITACIONAL',
#  'FRACCIONAMIENTO',
#  'UNIDAD HABITACIONAL',
#  'CIUDAD',
#  'MANZANA',
#  'EJIDO',
#  nan,
#  'VILLA',
#  'SECCIÃ\x83Â\x93N',
#  'PARAJE',
#  'CIUDAD INDUSTRIAL',
#  'AMPLIACIÃ\x83Â\x93N',
#  'ZONA INDUSTRIAL',
#  'PUERTO',
#  'CUARTEL',
#  'PARQUE INDUSTRIAL',
#  'PRIVADA',
#  'RANCHERÃ\x83Â\x8dA',
#  'UNIDAD',
#  'AEROPUERTO',
#  'HACIENDA',
#  'SECTOR',
#  'RINCONADA',
#  'PROLONGACIÃ\x83Â\x93N',
#  'CONDOMINIO',
#  'EXHACIENDA',
#  'RESIDENCIAL',
#  'CORREDOR INDUSTRIAL',
#  'RANCHO',
#  'FRACCIÃ\x83Â\x93N',
#  'ZONA MILITAR',
#  'CANTÃ\x83Â\x93N',
#  'GRANJA',
#  'ZONA FEDERAL',
#  'REGIÃ\x83Â\x93N',
#  'ZONA NAVAL']

# %%
grouped_denue_df = denue_df.groupby('Clave municipio')
grouped_denue_df.head()
# Out:
#        Unnamed: 0  Código Tipo de Industria       ID  \
# 0          174704                        46  2511586
# 1          540472                        81  2363713
# 2           23013                        31  2032449
# 3           86301                        46  2002299
# 4          399216                        56  2249276
# ...           ...                       ...      ...
# 32680       12555                        31  2479456
# 37694      144015                        46  2526129
# 48479      578474                        81  2526098
# 56033      218517                        46  2480352
# 64607      533237                        81  2526114
#
#                      Nombre de la Unidad Económica Razón social  \
# 0                        LONJA MERCANTIL HERNANDEZ          NaN
# 1                         ESTÃÂTICA UNISEX DIANA          NaN
# 2                               TORTILLERÃÂA 599          NaN
# 3                             ABARROTES SIN NOMBRE          NaN
# 4                                     INTERNET MIP          NaN
# ...                                            ...          ...
# 32680  PANADERÃÂA SAGRADO CORAZÃÂN DE JESÃÂS          NaN
# 37694                          FARMACIA CRISTO REY          NaN
# 48479                       TALACHERÃÂA MARTHITA          NaN
# 56033                     MISCELÃÂNEA SIN NOMBRE          NaN
# 64607                          ESTÃÂTICA MEDUSAS          NaN
#
#        Código de la clase de actividad SCIAN  \
# 0                                     461110
# 1                                     812110
# 2                                     311830
# 3                                     461110
# 4                                     561432
# ...                                      ...
# 32680                                 311812
# 37694                                 464111
# 48479                                 811191
# 56033                                 461110
# 64607                                 812110
#
#                          Nombre de clase de la actividad  \
# 0      Comercio al por menor en tiendas de abarrotes,...
# 1      Salones y clÃÂ­nicas de belleza y peluquerÃÂ­as
# 2      ElaboraciÃÂ³n de tortillas de maÃÂ­z y molie...
# 3      Comercio al por menor en tiendas de abarrotes,...
# 4                     Servicios de acceso a computadoras
# ...                                                  ...
# 32680                        PanificaciÃÂ³n tradicional
# 37694                         Farmacias sin minisÃÂºper
# 48479                     ReparaciÃÂ³n menor de llantas
# 56033  Comercio al por menor en tiendas de abarrotes,...
# 64607  Salones y clÃÂ­nicas de belleza y peluquerÃÂ­as
#
#       Descripcion estrato personal ocupado Tipo de vialidad  \
# 0                           0 a 5 personas            CALLE
# 1                           0 a 5 personas            CALLE
# 2                           0 a 5 personas            CALLE
# 3                           0 a 5 personas          AVENIDA
# 4                           0 a 5 personas            CALLE
# ...                                    ...              ...
# 32680                       0 a 5 personas            CALLE
# 37694                       0 a 5 personas            CALLE
# 48479                       0 a 5 personas            CALLE
# 56033                       0 a 5 personas          CERRADA
# 64607                       0 a 5 personas            CALLE
#
#                Nombre de la vialidad  ...                     Localidad  \
# 0                   NICOLÃÂS BRAVO  ...  SAN BARTOLOMÃÂ ATLATLAHUCA
# 1                FRANCISCO I. MADERO  ...                    IXTAPALUCA
# 2               AVENIDA SAN ÃÂNGEL  ...      CIUDAD NEZAHUALCÃÂYOTL
# 3                 PROGRESO MUNICIPAL  ...                      TULTEPEC
# 4      ZUMPANGO-REYES KILÃÂMETRO 9  ...              SAN SEBASTIÃÂN
# ...                              ...  ...                           ...
# 32680                  ISIDRO FABELA  ...                    OTZOLOAPAN
# 37694                        REFORMA  ...      SAN SIMÃÂN DE GUERRERO
# 48479                       ITURBIDE  ...      SAN SIMÃÂN DE GUERRERO
# 56033                        NINGUNO  ...      SAN SIMÃÂN DE GUERRERO
# 64607                       ITURBIDE  ...      SAN SIMÃÂN DE GUERRERO
#
#       Área geoestadí­stica básica  Manzana NÃÂºmero de telÃÂ©fono  \
# 0                              216       4             7.171710e+09
# 1                              904      12                      NaN
# 2                             1289       5                      NaN
# 3                              335       8                      NaN
# 4                              359      16                      NaN
# ...                            ...     ...                      ...
# 32680                           32       6                      NaN
# 37694                           36      32                      NaN
# 48479                           36      30                      NaN
# 56033                           36      30                      NaN
# 64607                           36       8                      NaN
#
#       Correo electrÃÂ³nico Sitio en Internet  Tipo de establecimiento  \
# 0                       NaN               NaN                     Fijo
# 1                       NaN               NaN                     Fijo
# 2                       NaN               NaN                     Fijo
# 3                       NaN               NaN                     Fijo
# 4                       NaN               NaN                     Fijo
# ...                     ...               ...                      ...
# 32680                   NaN               NaN                     Fijo
# 37694                   NaN               NaN                     Fijo
# 48479                   NaN               NaN                     Fijo
# 56033                   NaN               NaN                     Fijo
# 64607                   NaN               NaN                     Fijo
#
#          Latitud    Longitud Fecha de incorporación al DENUE
# 0      19.069133  -99.611156                          jul-10
# 1      19.290680  -98.902444                          dic-14
# 2      19.389040  -99.015859                          dic-14
# 3      19.680749  -99.136141                          jul-10
# 4      19.787891  -99.055222                          dic-14
# ...          ...         ...                             ...
# 32680  19.116980 -100.296360                          dic-14
# 37694  19.022494 -100.005793                          jul-10
# 48479  19.024668 -100.005050                          jul-10
# 56033  19.024399 -100.004918                          dic-14
# 64607  19.023001 -100.006270                          jul-10
#
# [625 rows x 43 columns]

# %%
count_est = denue_df["Clave municipio"].value_counts()
count_est.head()
# Out:
# 33     8547
# 58     5826
# 106    5445
# 57     3412
# 104    3269
# Name: Clave municipio, dtype: int64

# %%
count_numempl = grouped_denue_df["Descripcion estrato personal ocupado"].value_counts()
count_numempl.head(25)
# Out:
# Clave municipio  Descripcion estrato personal ocupado
# 1                0 a 5 personas                          158
#                  51 a 100 personas                         4
#                  6 a 10 personas                           3
#                  11 a 30 personas                          1
# 2                0 a 5 personas                          742
#                  6 a 10 personas                          20
#                  11 a 30 personas                         17
#                  31 a 50 personas                          3
#                  251 y más personas                        1
# 3                0 a 5 personas                           75
#                  6 a 10 personas                           6
#                  11 a 30 personas                          1
#                  251 y más personas                        1
# 4                0 a 5 personas                           55
#                  11 a 30 personas                          5
#                  6 a 10 personas                           1
# 5                0 a 5 personas                          276
#                  6 a 10 personas                          13
#                  11 a 30 personas                         11
#                  31 a 50 personas                          1
#                  51 a 100 personas                         1
# 6                0 a 5 personas                           95
#                  6 a 10 personas                           2
#                  31 a 50 personas                          1
# 7                0 a 5 personas                           46
# Name: Descripcion estrato personal ocupado, dtype: int64
